# %%
import sys

REPO_ROOT = "/Workspace/Repos/chandrakanthab@gmail.com/healthcare-data-platform"

if REPO_ROOT not in sys.path:
    sys.path.insert(0, REPO_ROOT)

print(REPO_ROOT)

# %%
import os

generator_path = os.path.join(
    REPO_ROOT,
    "src",
    "data_generator",
    "generate_emr.py"
)

print(generator_path)
print(os.path.exists(generator_path))

# %%
try:
    from faker import Faker
    print("✓ Faker is available")
except ImportError:
    print("✗ Faker is not available")

# %%
# %load_ext autoreload
# %autoreload 2
# Enables autoreload; learn more at https://docs.databricks.com/en/files/workspace-modules.html#autoreload-for-python-modules
# To disable autoreload; run %autoreload 0

# %%
# %pip install Faker

# %%
import sys

REPO_ROOT = "/Workspace/Repos/chandrakanthab@gmail.com/healthcare-data-platform"

if REPO_ROOT not in sys.path:
    sys.path.insert(0, REPO_ROOT)

print(REPO_ROOT)

import os

generator_path = os.path.join(
    REPO_ROOT,
    "src",
    "data_generator",
    "generate_emr.py"
)

print(generator_path)
print(os.path.exists(generator_path))

# %%
from src.data_generator.generate_emr import main


print("✓ EMR generator imported successfully")
print("✓ LIS generator imported successfully")

# %%
# from src.data_generator.generate_emr import main

# main()

# %%
# from src.data_generator.generate_lis import main
# main()
# print("✓ LIS generator imported successfully")

# %%
# from src.data_generator.generate_pharmacy import main
# main()
# print("✓ Pharmacy generator imported successfully")

# %%
# from src.data_generator.generate_billing import main
# main()
# print("✓ Billing generator imported successfully")

# %%
from src.data_generator.validate_cross_system import main
main()
print("✓ Cross-system validation completed successfully")
