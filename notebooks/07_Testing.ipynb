# %%
print("07_Testing")

# %%
# %sh
cd /Workspace/Repos/chandrakanthab@gmail.com/healthcare-data-platform
git sparse-checkout disable
git checkout HEAD

# %%
# %sh
cd /Workspace/Repos/chandrakanthab@gmail.com/healthcare-data-platform
git sparse-checkout list
